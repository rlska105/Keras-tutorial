# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
from random import randint
from sklearn.preprocessing import MinMaxScaler

train_labels = []
train_samples = []

for i in range(50):
    # The 5% of younger individuals who did experience side effects
    random_younger = randint(13,64)
    train_samples.append(random_younger)
    train_labels.append(1)

    # The 5% of older individuals who did not experience side effects
    random_older = randint(65,100)
    train_samples.append(random_older)
    train_labels.append(0)

for i in range(1000):
    # The 95% of younger individuals who did not experience side effects
    random_younger = randint(13,64)
    train_samples.append(random_younger)
    train_labels.append(0)

        # The 95% of older individuals who did experience side effects
    random_older = randint(65,100)
    train_samples.append(random_older)
    train_labels.append(1)
    
train_labels = np.array(train_labels)
train_samples = np.array(train_samples)

scaler = MinMaxScaler(feature_range=(0,1))
scaled_train_samples = scaler.fit_transform(train_samples.reshape(-1,1))

model = tf.keras.Sequential()
model.add(layers.Dense(16,input_shape=(1,), activation='relu'))
model.add(layers.Dense(32, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))

model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(x=scaled_train_samples, y=train_labels, validation_split=0.1, batch_size=10, epochs=20, shuffle=True, verbose=2)

model.summary()
# Out:
# Train on 1890 samples, validate on 210 samples
# Epoch 1/20
# 1890/1890 - 0s - loss: 0.6474 - accuracy: 0.6577 - val_loss: 0.4888 - val_accuracy: 0.9000
# Epoch 2/20
# 1890/1890 - 0s - loss: 0.3965 - accuracy: 0.8836 - val_loss: 0.2187 - val_accuracy: 0.9619
# Epoch 3/20
# 1890/1890 - 0s - loss: 0.2922 - accuracy: 0.9296 - val_loss: 0.1577 - val_accuracy: 0.9857
# Epoch 4/20
# 1890/1890 - 0s - loss: 0.2735 - accuracy: 0.9344 - val_loss: 0.1409 - val_accuracy: 1.0000
# Epoch 5/20
# 1890/1890 - 0s - loss: 0.2665 - accuracy: 0.9370 - val_loss: 0.1224 - val_accuracy: 0.9857
# Epoch 6/20
# 1890/1890 - 0s - loss: 0.2636 - accuracy: 0.9323 - val_loss: 0.1254 - val_accuracy: 1.0000
# Epoch 7/20
# 1890/1890 - 0s - loss: 0.2594 - accuracy: 0.9407 - val_loss: 0.1233 - val_accuracy: 1.0000
# Epoch 8/20
# 1890/1890 - 0s - loss: 0.2571 - accuracy: 0.9402 - val_loss: 0.1053 - val_accuracy: 0.9857
# Epoch 9/20
# 1890/1890 - 0s - loss: 0.2563 - accuracy: 0.9328 - val_loss: 0.1221 - val_accuracy: 0.9905
# Epoch 10/20
# 1890/1890 - 0s - loss: 0.2542 - accuracy: 0.9365 - val_loss: 0.1183 - val_accuracy: 0.9905
# Epoch 11/20
# 1890/1890 - 0s - loss: 0.2537 - accuracy: 0.9418 - val_loss: 0.1048 - val_accuracy: 0.9952
# Epoch 12/20
# 1890/1890 - 0s - loss: 0.2523 - accuracy: 0.9376 - val_loss: 0.1067 - val_accuracy: 1.0000
# Epoch 13/20
# 1890/1890 - 0s - loss: 0.2510 - accuracy: 0.9402 - val_loss: 0.0991 - val_accuracy: 0.9857
# Epoch 14/20
# 1890/1890 - 0s - loss: 0.2499 - accuracy: 0.9418 - val_loss: 0.1033 - val_accuracy: 1.0000
# Epoch 15/20
# 1890/1890 - 0s - loss: 0.2494 - accuracy: 0.9423 - val_loss: 0.0987 - val_accuracy: 0.9952
# Epoch 16/20
# 1890/1890 - 0s - loss: 0.2496 - accuracy: 0.9365 - val_loss: 0.1009 - val_accuracy: 0.9952
# Epoch 17/20
# 1890/1890 - 0s - loss: 0.2474 - accuracy: 0.9423 - val_loss: 0.0987 - val_accuracy: 0.9952
# Epoch 18/20
# 1890/1890 - 0s - loss: 0.2469 - accuracy: 0.9423 - val_loss: 0.0934 - val_accuracy: 0.9952
# Epoch 19/20
# 1890/1890 - 0s - loss: 0.2457 - accuracy: 0.9397 - val_loss: 0.1009 - val_accuracy: 0.9905
# Epoch 20/20
# 1890/1890 - 0s - loss: 0.2450 - accuracy: 0.9413 - val_loss: 0.0899 - val_accuracy: 0.9952
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_33 (Dense)             (None, 16)                32
# _________________________________________________________________
# dense_34 (Dense)             (None, 32)                544
# _________________________________________________________________
# dense_35 (Dense)             (None, 2)                 66
# =================================================================
# Total params: 642
# Trainable params: 642
# Non-trainable params: 0
# _________________________________________________________________
